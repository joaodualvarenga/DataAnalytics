# %% [markdown]
# Teste prático tratamento de dados

# %%
import pandas as pd
import seaborn as sea
import statistics as est

# %%
#importar os daoos
tabela = pd.read_csv("tempo.csv", sep=";")
tabela.head()
# Out:
#   Aparencia  Temperatura  Umidade       Vento Jogar
# 0       sol           85     85.0       FALSO   nao
# 1       sol           80     90.0  VERDADEIRO   nao
# 2   nublado           83     86.0       FALSO   sim
# 3     chuva           70      NaN       FALSO   sim
# 4     chuva           68     80.0       FALSO   sim

# %%
tabela.shape
# Out:
# (14, 5)

# %%
tabela
# Out:
#    Aparencia  Temperatura  Umidade       Vento Jogar
# 0        sol           85     85.0       FALSO   nao
# 1        sol           80     90.0  VERDADEIRO   nao
# 2    nublado           83     86.0       FALSO   sim
# 3      chuva           70      NaN       FALSO   sim
# 4      chuva           68     80.0       FALSO   sim
# 5      chuva           65     70.0  VERDADEIRO   nao
# 6      menos           64     65.0  VERDADEIRO   sim
# 7        sol         1220     95.0       FALSO   nao
# 8        sol           69     70.0       FALSO   sim
# 9      chuva           75    200.0         NaN   sim
# 10       sol           75     70.0  VERDADEIRO   sim
# 11   nublado           72     90.0  VERDADEIRO   sim
# 12   nublado           81     75.0       FALSO   sim
# 13     chuva           71     91.0  VERDADEIRO   nao

# %%
grupoA = tabela.groupby(['Aparencia']).size()
grupoA
# Out:
# Aparencia
# chuva      5
# menos      1
# nublado    3
# sol        5
# dtype: int64

# %%
tabela.isnull().sum()
# Out:
# Aparencia      0
# Temperatura    0
# Umidade        1
# Vento          1
# Jogar          0
# dtype: int64

# %%
mediana1 = est.median(tabela['Umidade'])
mediana1
# Out:
# 85.5

# %%
tabela['Umidade'].fillna(mediana1,inplace=True)

# %%
tabela
# Out:
#    Aparencia  Temperatura  Umidade       Vento Jogar
# 0        sol           85     85.0       FALSO   nao
# 1        sol           80     90.0  VERDADEIRO   nao
# 2    nublado           83     86.0       FALSO   sim
# 3      chuva           70     85.5       FALSO   sim
# 4      chuva           68     80.0       FALSO   sim
# 5      chuva           65     70.0  VERDADEIRO   nao
# 6      menos           64     65.0  VERDADEIRO   sim
# 7        sol         1220     95.0       FALSO   nao
# 8        sol           69     70.0       FALSO   sim
# 9      chuva           75    200.0         NaN   sim
# 10       sol           75     70.0  VERDADEIRO   sim
# 11   nublado           72     90.0  VERDADEIRO   sim
# 12   nublado           81     75.0       FALSO   sim
# 13     chuva           71     91.0  VERDADEIRO   nao

# %%
desv1 = est.stdev(tabela['Umidade'])
desv1
# Out:
# 33.204763493832004

# %%
sea.boxplot(tabela['Umidade'])
# Out:
# C:\Users\joao_\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Umidade'>

# %%
tabela.loc[tabela['Umidade'] > 100, 'Umidade'] = mediana1

# %%
tabela
# Out:
#    Aparencia  Temperatura  Umidade       Vento Jogar
# 0        sol           85     85.0       FALSO   nao
# 1        sol           80     90.0  VERDADEIRO   nao
# 2    nublado           83     86.0       FALSO   sim
# 3      chuva           70     85.5       FALSO   sim
# 4      chuva           68     80.0       FALSO   sim
# 5      chuva           65     70.0  VERDADEIRO   nao
# 6      menos           64     65.0  VERDADEIRO   sim
# 7        sol         1220     95.0       FALSO   nao
# 8        sol           69     70.0       FALSO   sim
# 9      chuva           75     85.5         NaN   sim
# 10       sol           75     70.0  VERDADEIRO   sim
# 11   nublado           72     90.0  VERDADEIRO   sim
# 12   nublado           81     75.0       FALSO   sim
# 13     chuva           71     91.0  VERDADEIRO   nao

# %%
NumVento = tabela.groupby(['Vento']).size()
NumVento
# Out:
# Vento
# FALSO         7
# VERDADEIRO    6
# dtype: int64

# %%
tabela['Vento'].fillna('FALSO',inplace = True)
tabela
# Out:
#    Aparencia  Temperatura  Umidade       Vento Jogar
# 0        sol           85     85.0       FALSO   nao
# 1        sol           80     90.0  VERDADEIRO   nao
# 2    nublado           83     86.0       FALSO   sim
# 3      chuva           70     85.5       FALSO   sim
# 4      chuva           68     80.0       FALSO   sim
# 5      chuva           65     70.0  VERDADEIRO   nao
# 6      menos           64     65.0  VERDADEIRO   sim
# 7        sol         1220     95.0       FALSO   nao
# 8        sol           69     70.0       FALSO   sim
# 9      chuva           75     85.5       FALSO   sim
# 10       sol           75     70.0  VERDADEIRO   sim
# 11   nublado           72     90.0  VERDADEIRO   sim
# 12   nublado           81     75.0       FALSO   sim
# 13     chuva           71     91.0  VERDADEIRO   nao

# %%
sea.boxplot(tabela['Temperatura'])
# Out:
# C:\Users\joao_\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Temperatura'>

# %%
mediana2 = est.median(tabela['Temperatura'])
mediana2
# Out:
# 73.5

# %%
tabela.loc[tabela['Temperatura']>150,'Temperatura'] = mediana2

# %%
tabela
# Out:
#    Aparencia  Temperatura  Umidade       Vento Jogar
# 0        sol         85.0     85.0       FALSO   nao
# 1        sol         80.0     90.0  VERDADEIRO   nao
# 2    nublado         83.0     86.0       FALSO   sim
# 3      chuva         70.0     85.5       FALSO   sim
# 4      chuva         68.0     80.0       FALSO   sim
# 5      chuva         65.0     70.0  VERDADEIRO   nao
# 6      menos         64.0     65.0  VERDADEIRO   sim
# 7        sol         73.5     95.0       FALSO   nao
# 8        sol         69.0     70.0       FALSO   sim
# 9      chuva         75.0     85.5       FALSO   sim
# 10       sol         75.0     70.0  VERDADEIRO   sim
# 11   nublado         72.0     90.0  VERDADEIRO   sim
# 12   nublado         81.0     75.0       FALSO   sim
# 13     chuva         71.0     91.0  VERDADEIRO   nao

# %%
NumAp = tabela.groupby(tabela['Aparencia']).size()
NumAp
# Out:
# Aparencia
# chuva      5
# menos      1
# nublado    3
# sol        5
# dtype: int64

# %%
tabela.loc[tabela['Aparencia'] == 'menos','Aparencia'] = 'chuva'

# %%
tabela
# Out:
#    Aparencia  Temperatura  Umidade       Vento Jogar
# 0        sol         85.0     85.0       FALSO   nao
# 1        sol         80.0     90.0  VERDADEIRO   nao
# 2    nublado         83.0     86.0       FALSO   sim
# 3      chuva         70.0     85.5       FALSO   sim
# 4      chuva         68.0     80.0       FALSO   sim
# 5      chuva         65.0     70.0  VERDADEIRO   nao
# 6      chuva         64.0     65.0  VERDADEIRO   sim
# 7        sol         73.5     95.0       FALSO   nao
# 8        sol         69.0     70.0       FALSO   sim
# 9      chuva         75.0     85.5       FALSO   sim
# 10       sol         75.0     70.0  VERDADEIRO   sim
# 11   nublado         72.0     90.0  VERDADEIRO   sim
# 12   nublado         81.0     75.0       FALSO   sim
# 13     chuva         71.0     91.0  VERDADEIRO   nao
